# %% [markdown]
# # Gesture Recognition
# In this project we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly.

# %%
# Importing the necessary libraries

import numpy as np
import os
import pandas as pd
from imageio import imread
from skimage.transform import resize as imresize
import datetime
import os
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
#Reinstates Pandas Plotting Converters to Use for Graphs
pd.plotting.register_matplotlib_converters()

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)
# tf.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
data_loc = "C:/Users\King/Desktop/Project_data"
train_doc = np.random.permutation(open(data_loc + '/train.csv').readlines())
val_doc = np.random.permutation(open(data_loc+'/val.csv').readlines())
batch_size = 8

# %% [markdown]
# #### Note : Initially tried with batch size 16, 32, 64 they didnt seem productive and for batches for sizes 32 and 64 had too much RAM consumption, Hence for Conv3D models 8 and 16 were providing good results

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. In the generator, We are going to preprocess the images as we have images of 2 different dimensions as well as create a batch of video frames. We have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = list(range(0,30,2))
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,len(img_idx),100,100,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image = imresize(image,(100,100))
                    batch_data[folder,idx,:,:,0] = image[:,:,0]/255
                    batch_data[folder,idx,:,:,1] = image[:,:,1]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2]/255                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        remaining = len(t) % batch_size
        print(remaining)
        if remaining != 0:
            batch_data = np.zeros((remaining,len(img_idx),100,100,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((remaining,5)) # batch_labels is the one hot representation of the output
            for folder in range(remaining): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*remaining)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*remaining)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image = imresize(image,(100,100))
                    batch_data[folder,idx,:,:,0] = image[:,:,0]/255
                    batch_data[folder,idx,:,:,1] = image[:,:,1]/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2]/255                    
                batch_labels[folder, int(t[folder + (batch*remaining)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
train_path = data_loc+'/train'
val_path = data_loc+'/val'

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
testGen = generator(train_path,train_doc,batch_size)

# %%
testGen = generator(train_path,train_doc,batch_size)
batch_data,batch_labels = next(testGen)
# Out:
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8

# %%
batch_data.shape
# Out:
# (8, 15, 100, 100, 3)

# %%
inputShape = batch_data[0].shape
inputShape
# Out:
# (15, 100, 100, 3)

# %% [markdown]
# #### Checking the input images

# %%
plt.figure(figsize=(20,10))
for i in range(1,6):
  ax = plt.subplot(2,10, i)
  plt.imshow(batch_data[2][i-1])

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Model
# Here we make the model using different functionalities that Keras provides. We use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. We would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. So we design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation,Dropout
from tensorflow.keras.layers import Conv3D, MaxPooling3D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam

from keras.applications import mobilenet #for transfer learning
from tensorflow.keras import backend as K

# %%
K.clear_session()

# %% [markdown]
# ## Model 1 : Using Conv3D

# %%
Input_shape = inputShape
model = Sequential()
model.add(Conv3D(16, (3,3,3), padding='same',
                 input_shape=Input_shape))
#model.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=sample_shape))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2,2)))
model.add(Dropout(0.2))


model.add(Conv3D(32, (3, 3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2,2)))
model.add(Dropout(0.2))

model.add(Conv3D(64, (3, 3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2,2)))
model.add(Dropout(0.2))



model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dense(128,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(5))
model.add(Activation('softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser =Adam(0.001) 
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 15, 100, 100, 16)  1312
#
#  activation (Activation)     (None, 15, 100, 100, 16)  0
#
#  max_pooling3d (MaxPooling3D  (None, 7, 50, 50, 16)    0
#  )
#
#  dropout (Dropout)           (None, 7, 50, 50, 16)     0
#
#  conv3d_1 (Conv3D)           (None, 7, 50, 50, 32)     13856
#
#  activation_1 (Activation)   (None, 7, 50, 50, 32)     0
#
#  max_pooling3d_1 (MaxPooling  (None, 3, 25, 25, 32)    0
#  3D)
#
#  dropout_1 (Dropout)         (None, 3, 25, 25, 32)     0
#
#  conv3d_2 (Conv3D)           (None, 3, 25, 25, 64)     55360
#
#  activation_2 (Activation)   (None, 3, 25, 25, 64)     0
#
#  max_pooling3d_2 (MaxPooling  (None, 1, 12, 12, 64)    0
#  3D)
#
#  dropout_2 (Dropout)         (None, 1, 12, 12, 64)     0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 64)                589888
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
- lr: 0.0010

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])
plot(history_basic)

# %% [markdown]
# #### Note:
#
# __With 10 epoch our training accuracy and validation accuracy came out to be good.__
#
# So now we will increase number of epochs and add some more dropout and regularization to overcome overfitting.

# %% [markdown]
# ## Model 2 : Using Conv3D

# %%
testGen = generator(train_path,train_doc,batch_size)
batch_data,batch_labels = next(testGen)
inputShape = batch_data[0].shape
inputShape
# Out:
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8
# (15, 100, 100, 3)

# %%
train_path = data_loc+'/train'
val_path = data_loc+'/val'
curr_dt_time = datetime.datetime.now()
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 20
print ('# epochs =', num_epochs)



Input_shape = inputShape
model_2 = Sequential()
model_2.add(Conv3D(16, (3,3,3), padding='same',
                 input_shape=Input_shape))
model_2.add(Activation('relu'))
model_2.add(MaxPooling3D(pool_size=(2, 2,2)))
model_2.add(Dropout(0.2))


model_2.add(Conv3D(32, (3, 3,3), padding='same'))
model_2.add(Activation('relu'))
model_2.add(MaxPooling3D(pool_size=(2, 2,2)))
model_2.add(Dropout(0.2))

model_2.add(Conv3D(64, (3, 3,3), padding='same'))
model_2.add(Activation('relu'))
model_2.add(MaxPooling3D(pool_size=(2, 2,2)))
model_2.add(Dropout(0.2))



model_2.add(Flatten())
model_2.add(Dense(64,kernel_regularizer=l2(0.01)))
model_2.add(Activation('relu'))
model_2.add(Dropout(0.3))
model_2.add(Dense(128,kernel_regularizer=l2(0.01)))
model_2.add(Activation('relu'))
model_2.add(Dropout(0.3))

model_2.add(Dense(5))
model_2.add(Activation('softmax'))

optimiser =Adam(0.001) #write your optimizer
model_2.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_2.summary())
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 15, 100, 100, 16)  1312
#
#  activation_6 (Activation)   (None, 15, 100, 100, 16)  0
#
#  max_pooling3d_3 (MaxPooling  (None, 7, 50, 50, 16)    0
#  3D)
#
#  dropout_4 (Dropout)         (None, 7, 50, 50, 16)     0
#
#  conv3d_4 (Conv3D)           (None, 7, 50, 50, 32)     13856
#
#  activation_7 (Activation)   (None, 7, 50, 50, 32)     0
#
#  max_pooling3d_4 (MaxPooling  (None, 3, 25, 25, 32)    0
#  3D)
#
#  dropout_5 (Dropout)         (None, 3, 25, 25, 32)     0
#
#  conv3d_5 (Conv3D)           (None, 3, 25, 25, 64)     55360
#
#  activation_8 (Activation)   (None, 3, 25, 25, 64)     0
#
#  max_pooling3d_5 (MaxPooling  (None, 1, 12, 12, 64)    0
#  3D)
#
#  dropout_6 (Dropout)         (None, 1, 12, 12, 64)     0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_3 (Dense)             (None, 64)                589888
#
#  activation_9 (Activation)   (None, 64)                0
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  activation_10 (Activation)  (None, 128)               0
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
#  activation_11 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 669,381
# Trainable params: 669,381
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)



model_name = 'Model_2' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
 

history_2 = model_2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8
# Epoch 1/20
# 81/83 [============================>.] - ETA: 5s - loss: 2.8053 - categorical_accuracy: 0.19147
# 83/83 [==============================] - ETA: 0s - loss: 2.7913 - categorical_accuracy: 0.1916Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 8
# 4
#
# Epoch 00001: val_loss improved from inf to 2.20009, saving model to Model_2_2022-01-0519_21_30.507305\model-00001-2.79129-0.19155-2.20009-0.23000.h5
# 83/83 [==============================] - 238s 3s/step - loss: 2.7913 - categorical_accuracy: 0.1916 - val_loss: 2.2001 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/20
# 81/83 [============================>.] - ETA: 5s - loss: 2.0025 - categorical_accuracy: 0.23467
# 83/83 [==============================] - ETA: 0s - loss: 1.9985 - categorical_accuracy: 0.23984
#
# Epoch 00002: val_loss improved from 2.20009 to 1.83921, saving model to Model_2_2022-01-0519_21_30.507305\model-00002-1.99853-0.23982-1.83921-0.39000.h5
# 83/83 [==============================] - 236s 3s/step - loss: 1.9985 - categorical_accuracy: 0.2398 - val_loss: 1.8392 - val_categorical_accuracy: 0.3900 - lr: 0.0010
# Epoch 3/20
# 81/83 [============================>.] - ETA: 5s - loss: 1.6722 - categorical_accuracy: 0.30097
# 83/83 [==============================] - ETA: 0s - loss: 1.6647 - categorical_accuracy: 0.30474
#
# Epoch 00003: val_loss improved from 1.83921 to 1.40240, saving model to Model_2_2022-01-0519_21_30.507305\model-00003-1.66472-0.30468-1.40240-0.52000.h5
# 83/83 [==============================] - 236s 3s/step - loss: 1.6647 - categorical_accuracy: 0.3047 - val_loss: 1.4024 - val_categorical_accuracy: 0.5200 - lr: 0.0010
# Epoch 4/20
# 81/83 [============================>.] - ETA: 5s - loss: 1.3688 - categorical_accuracy: 0.45837
# 83/83 [==============================] - ETA: 0s - loss: 1.3636 - categorical_accuracy: 0.46154
#
# Epoch 00004: val_loss improved from 1.40240 to 1.26302, saving model to Model_2_2022-01-0519_21_30.507305\model-00004-1.36362-0.46154-1.26302-0.49000.h5
# 83/83 [==============================] - 241s 3s/step - loss: 1.3636 - categorical_accuracy: 0.4615 - val_loss: 1.2630 - val_categorical_accuracy: 0.4900 - lr: 0.0010
# Epoch 5/20
# 81/83 [============================>.] - ETA: 5s - loss: 1.1892 - categorical_accuracy: 0.53557
# 83/83 [==============================] - ETA: 0s - loss: 1.1897 - categorical_accuracy: 0.53394
#
# Epoch 00005: val_loss improved from 1.26302 to 1.15676, saving model to Model_2_2022-01-0519_21_30.507305\model-00005-1.18968-0.53394-1.15676-0.57000.h5
# 83/83 [==============================] - 238s 3s/step - loss: 1.1897 - categorical_accuracy: 0.5339 - val_loss: 1.1568 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 6/20
# 81/83 [============================>.] - ETA: 5s - loss: 1.0900 - categorical_accuracy: 0.58957
# 83/83 [==============================] - ETA: 0s - loss: 1.0882 - categorical_accuracy: 0.59134
#
# Epoch 00006: val_loss improved from 1.15676 to 1.02848, saving model to Model_2_2022-01-0519_21_30.507305\model-00006-1.08815-0.59125-1.02848-0.65000.h5
# 83/83 [==============================] - 236s 3s/step - loss: 1.0882 - categorical_accuracy: 0.5913 - val_loss: 1.0285 - val_categorical_accuracy: 0.6500 - lr: 0.0010
# Epoch 7/20
# 81/83 [============================>.] - ETA: 5s - loss: 1.0024 - categorical_accuracy: 0.62197
# 83/83 [==============================] - ETA: 0s - loss: 1.0109 - categorical_accuracy: 0.61994
#
# Epoch 00007: val_loss did not improve from 1.02848
# 83/83 [==============================] - 236s 3s/step - loss: 1.0109 - categorical_accuracy: 0.6199 - val_loss: 1.0289 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 8/20
# 81/83 [============================>.] - ETA: 5s - loss: 0.9161 - categorical_accuracy: 0.66677
# 83/83 [==============================] - ETA: 0s - loss: 0.9131 - categorical_accuracy: 0.66524
#
# Epoch 00008: val_loss improved from 1.02848 to 0.86859, saving model to Model_2_2022-01-0519_21_30.507305\model-00008-0.91314-0.66516-0.86859-0.68000.h5
# 83/83 [==============================] - 237s 3s/step - loss: 0.9131 - categorical_accuracy: 0.6652 - val_loss: 0.8686 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 9/20
# 81/83 [============================>.] - ETA: 5s - loss: 0
- val_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 18/20
# 81/83 [============================>.] - ETA: 5s - loss: 0.5057 - categorical_accuracy: 0.89667
# 83/83 [==============================] - ETA: 0s - loss: 0.5089 - categorical_accuracy: 0.89594
#
# Epoch 00018: val_loss improved from 0.58131 to 0.52708, saving model to Model_2_2022-01-0519_21_30.507305\model-00018-0.50886-0.89593-0.52708-0.87000.h5
# 83/83 [==============================] - 237s 3s/step - loss: 0.5089 - categorical_accuracy: 0.8959 - val_loss: 0.5271 - val_categorical_accuracy: 0.8700 - lr: 5.0000e-04
# Epoch 19/20
# 81/83 [============================>.] - ETA: 5s - loss: 0.4403 - categorical_accuracy: 0.91677
# 83/83 [==============================] - ETA: 0s - loss: 0.4410 - categorical_accuracy: 0.91704
#
# Epoch 00019: val_loss did not improve from 0.52708
# 83/83 [==============================] - 239s 3s/step - loss: 0.4410 - categorical_accuracy: 0.9170 - val_loss: 0.5484 - val_categorical_accuracy: 0.8500 - lr: 5.0000e-04
# Epoch 20/20
# 81/83 [============================>.] - ETA: 5s - loss: 0.4474 - categorical_accuracy: 0.91207
# 83/83 [==============================] - ETA: 0s - loss: 0.4476 - categorical_accuracy: 0.91254
#
# Epoch 00020: val_loss improved from 0.52708 to 0.49769, saving model to Model_2_2022-01-0519_21_30.507305\model-00020-0.44761-0.91252-0.49769-0.89000.h5
# 83/83 [==============================] - 238s 3s/step - loss: 0.4476 - categorical_accuracy: 0.9125 - val_loss: 0.4977 - val_categorical_accuracy: 0.8900 - lr: 5.0000e-04

# %%
plot(history_2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Note:
#
# _We did observe an improvement in accuracy for both training and validation._
#
# But lets try to make it more steady.

# %% [markdown]
# ## Model 3 : Using Conv3D

# %% [markdown]
# ##### Lets have a Model with more dropout percentage

# %%
testGen = generator(train_path,train_doc,batch_size)
batch_data,batch_labels = next(testGen)
inputShape = batch_data[0].shape
inputShape
# Out:
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8
# (15, 100, 100, 3)

# %%
train_path = data_loc+'/train'
val_path = data_loc+'/val'
curr_dt_time = datetime.datetime.now()
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 25
print ('# epochs =', num_epochs)


Input_shape = inputShape
model_3 = Sequential()
model_3.add(Conv3D(16, (3,3,3), padding='same',
                 input_shape=Input_shape))
#model_3.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=sample_shape))
model_3.add(Activation('relu'))
model_3.add(MaxPooling3D(pool_size=(2, 2,2)))
model_3.add(Dropout(0.3))


model_3.add(Conv3D(32, (3, 3,3), padding='same'))
model_3.add(Activation('relu'))
model_3.add(MaxPooling3D(pool_size=(2, 2,2)))
model_3.add(Dropout(0.3))

model_3.add(Conv3D(64, (3, 3,3), padding='same'))
model_3.add(Activation('relu'))
model_3.add(MaxPooling3D(pool_size=(2, 2,2)))
model_3.add(Dropout(0.2))



model_3.add(Flatten())
model_3.add(Dense(64,kernel_regularizer=l2(0.01)))
model_3.add(Activation('relu'))
model_3.add(Dropout(0.4))
model_3.add(Dense(128,kernel_regularizer=l2(0.01)))
model_3.add(Activation('relu'))
model_3.add(Dropout(0.4))

model_3.add(Dense(5))
model_3.add(Activation('softmax'))

optimiser =Adam(0.001) #write your optimizer
model_3.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_3.summary())
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 25
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_6 (Conv3D)           (None, 15, 100, 100, 16)  1312
#
#  activation_12 (Activation)  (None, 15, 100, 100, 16)  0
#
#  max_pooling3d_6 (MaxPooling  (None, 7, 50, 50, 16)    0
#  3D)
#
#  dropout_9 (Dropout)         (None, 7, 50, 50, 16)     0
#
#  conv3d_7 (Conv3D)           (None, 7, 50, 50, 32)     13856
#
#  activation_13 (Activation)  (None, 7, 50, 50, 32)     0
#
#  max_pooling3d_7 (MaxPooling  (None, 3, 25, 25, 32)    0
#  3D)
#
#  dropout_10 (Dropout)        (None, 3, 25, 25, 32)     0
#
#  conv3d_8 (Conv3D)           (None, 3, 25, 25, 64)     55360
#
#  activation_14 (Activation)  (None, 3, 25, 25, 64)     0
#
#  max_pooling3d_8 (MaxPooling  (None, 1, 12, 12, 64)    0
#  3D)
#
#  dropout_11 (Dropout)        (None, 1, 12, 12, 64)     0
#
#  flatten_2 (Flatten)         (None, 9216)              0
#
#  dense_6 (Dense)             (None, 64)                589888
#
#  activation_15 (Activation)  (None, 64)                0
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  activation_16 (Activation)  (None, 128)               0
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
#  activation_17 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 669,381
# Trainable params: 669,381
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)



model_name = 'Model_3' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
 

history_3 = model_3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8
# Epoch 1/25
# 81/83 [============================>.] - ETA: 8s - loss: 2.8682 - categorical_accuracy: 0.2222 7
# 83/83 [==============================] - ETA: 0s - loss: 2.8553 - categorical_accuracy: 0.2187Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 8
# 4
#
# Epoch 00001: val_loss improved from inf to 2.28322, saving model to Model_3_2022-01-0520_41_07.368160\model-00001-2.85534-0.21870-2.28322-0.23000.h5
# 83/83 [==============================] - 369s 4s/step - loss: 2.8553 - categorical_accuracy: 0.2187 - val_loss: 2.2832 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/25
# 81/83 [============================>.] - ETA: 11s - loss: 2.0644 - categorical_accuracy: 0.19297
# 83/83 [==============================] - ETA: 0s - loss: 2.0610 - categorical_accuracy: 0.19164
#
# Epoch 00002: val_loss improved from 2.28322 to 1.90082, saving model to Model_3_2022-01-0520_41_07.368160\model-00002-2.06097-0.19155-1.90082-0.32000.h5
# 83/83 [==============================] - 499s 6s/step - loss: 2.0610 - categorical_accuracy: 0.1916 - val_loss: 1.9008 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 3/25
# 81/83 [============================>.] - ETA: 11s - loss: 1.8238 - categorical_accuracy: 0.22537
# 83/83 [==============================] - ETA: 0s - loss: 1.8219 - categorical_accuracy: 0.22784
#
# Epoch 00003: val_loss improved from 1.90082 to 1.73205, saving model to Model_3_2022-01-0520_41_07.368160\model-00003-1.82195-0.22775-1.73205-0.28000.h5
# 83/83 [==============================] - 504s 6s/step - loss: 1.8219 - categorical_accuracy: 0.2278 - val_loss: 1.7321 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 4/25
# 81/83 [============================>.] - ETA: 10s - loss: 1.6228 - categorical_accuracy: 0.30407
# 83/83 [==============================] - ETA: 0s - loss: 1.6258 - categorical_accuracy: 0.29864
#
# Epoch 00004: val_loss improved from 1.73205 to 1.60610, saving model to Model_3_2022-01-0520_41_07.368160\model-00004-1.62584-0.29864-1.60610-0.39000.h5
# 83/83 [==============================] - 472s 6s/step - loss: 1.6258 - categorical_accuracy: 0.2986 - val_loss: 1.6061 - val_categorical_accuracy: 0.3900 - lr: 0.0010
# Epoch 5/25
# 81/83 [============================>.] - ETA: 8s - loss: 1.5133 - categorical_accuracy: 0.3735 7
# 83/83 [==============================] - ETA: 0s - loss: 1.5076 - categorical_accuracy: 0.37714
#
# Epoch 00005: val_loss improved from 1.60610 to 1.45412, saving model to Model_3_2022-01-0520_41_07.368160\model-00005-1.50761-0.37707-1.45412-0.44000.h5
# Epoch 20/25
# 81/83 [============================>.] - ETA: 10s - loss: 0.5695 - categorical_accuracy: 0.86117
# 83/83 [==============================] - ETA: 0s - loss: 0.5745 - categorical_accuracy: 0.85974
#
# Epoch 00020: val_loss improved from 0.67288 to 0.47003, saving model to Model_3_2022-01-0520_41_07.368160\model-00020-0.57448-0.85973-0.47003-0.93000.h5
# 83/83 [==============================] - 443s 5s/step - loss: 0.5745 - categorical_accuracy: 0.8597 - val_loss: 0.4700 - val_categorical_accuracy: 0.9300 - lr: 5.0000e-04
# Epoch 21/25
# 81/83 [============================>.] - ETA: 10s - loss: 0.5385 - categorical_accuracy: 0.86737
# 83/83 [==============================] - ETA: 0s - loss: 0.5414 - categorical_accuracy: 0.86734
#
# Epoch 00021: val_loss did not improve from 0.47003
# 83/83 [==============================] - 453s 5s/step - loss: 0.5414 - categorical_accuracy: 0.8673 - val_loss: 0.7556 - val_categorical_accuracy: 0.8300 - lr: 5.0000e-04
# Epoch 22/25
# 81/83 [============================>.] - ETA: 9s - loss: 0.5158 - categorical_accuracy: 0.8796 7
# 83/83 [==============================] - ETA: 0s - loss: 0.5198 - categorical_accuracy: 0.87934
#
# Epoch 00022: val_loss did not improve from 0.47003
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 83/83 [==============================] - 412s 5s/step - loss: 0.5198 - categorical_accuracy: 0.8793 - val_loss: 0.7646 - val_categorical_accuracy: 0.8500 - lr: 5.0000e-04
# Epoch 23/25
# 81/83 [============================>.] - ETA: 10s - loss: 0.4895 - categorical_accuracy: 0.89977
# 83/83 [==============================] - ETA: 0s - loss: 0.4914 - categorical_accuracy: 0.89894
#
# Epoch 00023: val_loss did not improve from 0.47003
# 83/83 [==============================] - 474s 6s/step - loss: 0.4914 - categorical_accuracy: 0.8989 - val_loss: 0.5617 - val_categorical_accuracy: 0.8700 - lr: 2.5000e-04
# Epoch 24/25
# 81/83 [============================>.] - ETA: 10s - loss: 0.4531 - categorical_accuracy: 0.91207
# 83/83 [==============================] - ETA: 0s - loss: 0.4554 - categorical_accuracy: 0.91104
#
# Epoch 00024: val_loss did not improve from 0.47003
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 83/83 [==============================] - 461s 6s/step - loss: 0.4554 - categorical_accuracy: 0.9110 - val_loss: 0.5718 - val_categorical_accuracy: 0.9100 - lr: 2.5000e-04
# Epoch 25/25
# 81/83 [============================>.] - ETA: 9s - loss: 0.3851 - categorical_accuracy: 0.9414 7
# 83/83 [==============================] - ETA: 0s - loss: 0.3854 - categorical_accuracy: 0.94124
#
# Epoch 00025: val_loss did not improve from 0.47003
# 83/83 [==============================] - 414s 5s/step - loss: 0.3854 - categorical_accuracy: 0.9412 - val_loss: 0.5699 - val_categorical_accuracy: 0.8800 - lr: 1.2500e-04

# %%
plot(history_3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observation:**
#
# - Loss and Val loss looks good.
# - But there is alot of fluctuation on accuracy graph.
# - So in the next model we will increase the number of epochs and give more time to model for learning.

# %% [markdown]
# ## Model 4 : Using Conv3D

# %%
testGen = generator(train_path,train_doc,batch_size)
batch_data,batch_labels = next(testGen)
inputShape = batch_data[0].shape
inputShape
# Out:
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8
# (15, 100, 100, 3)

# %%
train_path = data_loc+'/train'
val_path = data_loc+'/val'
curr_dt_time = datetime.datetime.now()
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 40
print ('# epochs =', num_epochs)


Input_shape = inputShape
model_3_1 = Sequential()
model_3_1.add(Conv3D(16, (3,3,3), padding='same',
                 input_shape=Input_shape))
#model_3_1.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=sample_shape))
model_3_1.add(Activation('relu'))
model_3_1.add(MaxPooling3D(pool_size=(2, 2,2)))
model_3_1.add(Dropout(0.3))


model_3_1.add(Conv3D(32, (3, 3,3), padding='same'))
model_3_1.add(Activation('relu'))
model_3_1.add(MaxPooling3D(pool_size=(2, 2,2)))
model_3_1.add(Dropout(0.3))

model_3_1.add(Conv3D(64, (3, 3,3), padding='same'))
model_3_1.add(Activation('relu'))
model_3_1.add(MaxPooling3D(pool_size=(2, 2,2)))
model_3_1.add(Dropout(0.2))



model_3_1.add(Flatten())
model_3_1.add(Dense(64,kernel_regularizer=l2(0.01)))
model_3_1.add(Activation('relu'))
model_3_1.add(Dropout(0.4))
model_3_1.add(Dense(128,kernel_regularizer=l2(0.01)))
model_3_1.add(Activation('relu'))
model_3_1.add(Dropout(0.4))

model_3_1.add(Dense(5))
model_3_1.add(Activation('softmax'))

optimiser =Adam(0.001) #write your optimizer
model_3_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_3_1.summary())
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 40
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_9 (Conv3D)           (None, 15, 100, 100, 16)  1312
#
#  activation_18 (Activation)  (None, 15, 100, 100, 16)  0
#
#  max_pooling3d_9 (MaxPooling  (None, 7, 50, 50, 16)    0
#  3D)
#
#  dropout_14 (Dropout)        (None, 7, 50, 50, 16)     0
#
#  conv3d_10 (Conv3D)          (None, 7, 50, 50, 32)     13856
#
#  activation_19 (Activation)  (None, 7, 50, 50, 32)     0
#
#  max_pooling3d_10 (MaxPoolin  (None, 3, 25, 25, 32)    0
#  g3D)
#
#  dropout_15 (Dropout)        (None, 3, 25, 25, 32)     0
#
#  conv3d_11 (Conv3D)          (None, 3, 25, 25, 64)     55360
#
#  activation_20 (Activation)  (None, 3, 25, 25, 64)     0
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 12, 12, 64)    0
#  g3D)
#
#  dropout_16 (Dropout)        (None, 1, 12, 12, 64)     0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_9 (Dense)             (None, 64)                589888
#
#  activation_21 (Activation)  (None, 64)                0
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_10 (Dense)            (None, 128)               8320
#
#  activation_22 (Activation)  (None, 128)               0
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
#  activation_23 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 669,381
# Trainable params: 669,381
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)



model_name = 'Model_3_1' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
 

history_3_1 = model_3_1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 8
# Epoch 1/40
# 81/83 [============================>.] - ETA: 8s - loss: 2.8076 - categorical_accuracy: 0.2253 7
# 83/83 [==============================] - ETA: 0s - loss: 2.7945 - categorical_accuracy: 0.2278Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 8
# 4
#
# Epoch 00001: val_loss improved from inf to 2.22573, saving model to Model_3_1_2022-01-0523_31_18.570264\model-00001-2.79454-0.22775-2.22573-0.41000.h5
# 83/83 [==============================] - 377s 5s/step - loss: 2.7945 - categorical_accuracy: 0.2278 - val_loss: 2.2257 - val_categorical_accuracy: 0.4100 - lr: 0.0010
# Epoch 2/40
# 81/83 [============================>.] - ETA: 8s - loss: 1.9019 - categorical_accuracy: 0.3549 7
# 83/83 [==============================] - ETA: 0s - loss: 1.8909 - categorical_accuracy: 0.35604
#
# Epoch 00002: val_loss improved from 2.22573 to 1.48157, saving model to Model_3_1_2022-01-0523_31_18.570264\model-00002-1.89088-0.35596-1.48157-0.53000.h5
# 83/83 [==============================] - 384s 5s/step - loss: 1.8909 - categorical_accuracy: 0.3560 - val_loss: 1.4816 - val_categorical_accuracy: 0.5300 - lr: 0.0010
# Epoch
40
# 81/83 [============================>.] - ETA: 5s - loss: 0.3772 - categorical_accuracy: 0.92447
# 83/83 [==============================] - ETA: 0s - loss: 0.3750 - categorical_accuracy: 0.92614
#
# Epoch 00036: val_loss did not improve from 0.53569
# 83/83 [==============================] - 237s 3s/step - loss: 0.3750 - categorical_accuracy: 0.9261 - val_loss: 0.5931 - val_categorical_accuracy: 0.8600 - lr: 1.9531e-06
# Epoch 37/40
# 81/83 [============================>.] - ETA: 5s - loss: 0.4021 - categorical_accuracy: 0.93067
# 83/83 [==============================] - ETA: 0s - loss: 0.4005 - categorical_accuracy: 0.93214
#
# Epoch 00037: val_loss did not improve from 0.53569
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 83/83 [==============================] - 236s 3s/step - loss: 0.4005 - categorical_accuracy: 0.9321 - val_loss: 0.5419 - val_categorical_accuracy: 0.8900 - lr: 1.9531e-06
# Epoch 38/40
# 81/83 [============================>.] - ETA: 5s - loss: 0.3782 - categorical_accuracy: 0.92757
# 83/83 [==============================] - ETA: 0s - loss: 0.3753 - categorical_accuracy: 0.92914
#
# Epoch 00038: val_loss did not improve from 0.53569
# 83/83 [==============================] - 236s 3s/step - loss: 0.3753 - categorical_accuracy: 0.9291 - val_loss: 0.6506 - val_categorical_accuracy: 0.8500 - lr: 9.7656e-07
# Epoch 39/40
# 81/83 [============================>.] - ETA: 5s - loss: 0.3763 - categorical_accuracy: 0.93837
# 83/83 [==============================] - ETA: 0s - loss: 0.3784 - categorical_accuracy: 0.93824
# 4
#
# Epoch 00039: val_loss did not improve from 0.53569
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 83/83 [==============================] - 234s 3s/step - loss: 0.3784 - categorical_accuracy: 0.9382 - val_loss: 0.5556 - val_categorical_accuracy: 0.8700 - lr: 9.7656e-07
# Epoch 40/40
# 81/83 [============================>.] - ETA: 5s - loss: 0.3632 - categorical_accuracy: 0.93677
# 83/83 [==============================] - ETA: 0s - loss: 0.3645 - categorical_accuracy: 0.93674
#
# Epoch 00040: val_loss did not improve from 0.53569
# 83/83 [==============================] - 235s 3s/step - loss: 0.3645 - categorical_accuracy: 0.9367 - val_loss: 0.5616 - val_categorical_accuracy: 0.8800 - lr: 4.8828e-07

# %%
plot(history_3_1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observation:**
# - Model is fairly good.
# - We have least number of fluctuation in the end.
# - So far this is the best model using Conv3D.

# %% [markdown]
# #### Now Lets try with Conv2D + RNN models, We will use Tansfer Learnging + GRU

# %% [markdown]
# ## Model 5 : Using Conv2D + RNN  (Transfer Learning + GRU base model)

# %%
batch_size = 16

# %%
testGen = generator(train_path,train_doc,batch_size)
batch_data,batch_labels = next(testGen)
inputShape = batch_data[0].shape
inputShape
# Out:
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 16
# (15, 100, 100, 3)

# %%
train_path = data_loc+'/train'
val_path = data_loc+'/val'
curr_dt_time = datetime.datetime.now()
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
model_name = 'Model_3_1' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


# Model 1 (Transfer Learning + GRU) Basic
mobilenet_TL = mobilenet.MobileNet(weights='imagenet', include_top=False)
model_gru_1 = Sequential()
model_gru_1.add(TimeDistributed(mobilenet_TL,input_shape=inputShape))

model_gru_1.add(TimeDistributed(BatchNormalization()))
model_gru_1.add(TimeDistributed(MaxPooling2D((2, 2))))
model_gru_1.add(TimeDistributed(Flatten()))

model_gru_1.add(GRU(64))
model_gru_1.add(Dropout(0.3))

model_gru_1.add(Dense(64,activation='relu'))
model_gru_1.add(Dropout(0.3))

model_gru_1.add(Dense(5, activation='softmax'))

optimiser =Adam(0.001) #write your optimizer
model_gru_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_gru_1.summary())

# creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

num_epochs=10
model_gru_1=model_gru_1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,callbacks=callbacks_list, 
                    validation_data=val_generator,validation_steps=validation_steps,class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 15, 3, 3, 1024)   3228864
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 15, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 15, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 15, 1024)         0
#  tributed)
#
#  gru (GRU)                   (None, 64)                209280
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_13 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 3,446,725
# Trainable params: 3,422,789
# Non-trainable params: 23,936
# _________________________________________________________________
# None
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 16
# Epoch 1/10
# 40/42 [===========================>..] - ETA: 9s - loss: 1.1793 - categorical_accuracy: 0.5359 7
# 42/42 [==============================] - ETA: 0s - loss: 1.1576 - categorical_accuracy: 0.5460Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 16
# 4
#
# Epoch 00001: val_loss improved from inf to 0.87595, saving model to Model_3_1_2022-01-0602_26_13.102719\model-00001-1.15764-0.54600-0.87595-0.63000.h5
# 42/42 [==============================] - 213s 5s/step - loss: 1.1576 - categorical_accuracy: 0.5460 - val_loss: 0.8760 - val_categorical_accuracy: 0.6300 - lr: 0.0010
# Epoch 2/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.4430 - categorical_accuracy: 0.8672 7
# 42/42 [==============================] - ETA: 0s - loss: 0.4390 - categorical_accuracy: 0.86884
#
# Epoch 00002: val_loss improved from 0.87595 to 0.58578, saving model to Model_3_1_2022-01-0602_26_13.102719\model-00002-0.43903-0.86878-0.58578-0.77000.h5
# 42/42 [==============================] - 218s 5s/step - loss: 0.4390 - categorical_accuracy: 0.8688 - val_loss: 0.5858 - val_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 3/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.2085 - categorical_accuracy: 0.9375 7
# 42/42 [==============================] - ETA: 0s - loss: 0.2059 - categorical_accuracy: 0.93824
#
# Epoch 00003: val_loss improved from 0.58578 to 0.25812, saving model to Model_3_1_2022-01-0602_26_13.102719\model-00003-0.20595-0.93816-0.25812-0.88000.h5
# 42/42 [==============================] - 217s 5s/step - loss: 0.2059 - categorical_accuracy: 0.9382 - val_loss: 0.2581 - val_categorical_accuracy: 0.8800 - lr: 0.0010
# Epoch 4/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1241 - categorical_accuracy: 0.9719 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1260 - categorical_accuracy: 0.97134
#
# Epoch 00004: val_loss did not improve from 0.25812
# 42/42 [==============================] - 219s 5s/step - loss: 0.1260 - categorical_accuracy: 0.9713 - val_loss: 0.3393 - val_categorical_accuracy: 0.9200 - lr: 0.0010
# Epoch 5/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1714 - categorical_accuracy: 0.9484 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1752 - categorical_accuracy: 0.94574
#
# Epoch 00005: val_loss did not improve from 0.25812
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 220s 5s/step - loss: 0.1752 - categorical_accuracy: 0.9457 - val_loss: 0.7656 - val_categorical_accuracy: 0.8400 - lr: 0.0010
# Epoch 6/10
# 40/42 [===========================>..] - ETA: 10s - loss: 0.1047 - categorical_accuracy: 0.96887
# 42/42 [==============================] - ETA: 0s - loss: 0.1017 - categorical_accuracy: 0.96984
#
# Epoch 00006: val_loss improved from 0.25812 to 0.16147, saving model to Model_3_1_2022-01-0602_26_13.102719\model-00006-0.10165-0.96983-0.16147-0.95000.h5
# 42/42 [==============================] - 223s 5s/step - loss: 0.1017 - categorical_accuracy: 0.9698 - val_loss: 0.1615 - val_categorical_accuracy: 0.9500 - lr: 5.0000e-04
# Epoch 7/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0523 - categorical_accuracy: 0.9875 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0527 - categorical_accuracy: 0.98644
# 4
#
# Epoch 00007: val_loss did not improve from 0.16147
# 42/42 [==============================] - 218s 5s/step - loss: 0.0527 - categorical_accuracy: 0.9864 - val_loss: 0.2730 - val_categorical_accuracy: 0.9100 - lr: 5.0000e-04
# Epoch 8/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0635 - categorical_accuracy: 0.9781 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0616 - categorical_accuracy: 0.97894
#
# Epoch 00008: val_loss did not improve from 0.16147
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 219s 5s/step - loss: 0.0616 - categorical_accuracy: 0.9789 - val_loss: 0.2079 - val_categorical_accuracy: 0.9500 - lr: 5.0000e-04
# Epoch 9/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0356 - categorical_accuracy: 0.9906 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0364 - categorical_accuracy: 0.98944
#
# Epoch 00009: val_loss improved from 0.16147 to 0.04923, saving model to Model_3_1_2022-01-0602_26_13.102719\model-00009-0.03642-0.98944-0.04923-0.96000.h5
# 42/42 [==============================] - 219s 5s/step - loss: 0.0364 - categorical_accuracy: 0.9894 - val_loss: 0.0492 - val_categorical_accuracy: 0.9600 - lr: 2.5000e-04
# Epoch 10/10
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0277 - categorical_accuracy: 0.9953 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0275 - categorical_accuracy: 0.99554
#
# Epoch 00010: val_loss did not improve from 0.04923
# 42/42 [==============================] - 219s 5s/step - loss: 0.0275 - categorical_accuracy: 0.9955 - val_loss: 0.1258 - val_categorical_accuracy: 0.9500 - lr: 2.5000e-04

# %%
plot(model_gru_1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observations:**
#
# - Getting approx 95 training accuracy and 92 validation accuracy.
# - Will experiment by removing the dropout in the next model.

# %% [markdown]
# ## Model 6 : Using Conv2D + RNN  (Transfer Learning + GRU base model)

# %% [markdown]
# ##### Reduced dropout and checking again for 5 epoch

# %%
model_name = 'Model_TL_GRU_2' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


# Model 1 (Transfer Learning + GRU) Basic
mobilenet_TL = mobilenet.MobileNet(weights='imagenet', include_top=False)
model_gru_2 = Sequential()
model_gru_2.add(TimeDistributed(mobilenet_TL,input_shape=inputShape))

model_gru_2.add(TimeDistributed(BatchNormalization()))
model_gru_2.add(TimeDistributed(MaxPooling2D((2, 2))))
model_gru_2.add(TimeDistributed(Flatten()))

model_gru_2.add(GRU(64))
model_gru_2.add(Dropout(0.2))

model_gru_2.add(Dense(64,activation='relu'))

model_gru_2.add(Dense(5, activation='softmax'))

optimiser =Adam(0.001) #write your optimizer
model_gru_2.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_gru_2.summary())

# Creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

num_epochs=5
model_gru_2=model_gru_2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,callbacks=callbacks_list, 
                    validation_data=val_generator,validation_steps=validation_steps,class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_4 (TimeDis  (None, 15, 3, 3, 1024)   3228864
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 15, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 15, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 15, 1024)         0
#  tributed)
#
#  gru_1 (GRU)                 (None, 64)                209280
#
#  dropout_21 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dense_15 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 3,446,725
# Trainable params: 3,422,789
# Non-trainable params: 23,936
# _________________________________________________________________
# None
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 16
# Epoch 1/5
# 40/42 [===========================>..] - ETA: 9s - loss: 0.9691 - categorical_accuracy: 0.6422 7
# 42/42 [==============================] - ETA: 0s - loss: 0.9441 - categorical_accuracy: 0.6531Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 16
# 4
#
# Epoch 00001: val_loss improved from inf to 0.79425, saving model to Model_TL_GRU_2_2022-01-0602_26_13.102719\model-00001-0.94408-0.65309-0.79425-0.69000.h5
# 42/42 [==============================] - 207s 5s/step - loss: 0.9441 - categorical_accuracy: 0.6531 - val_loss: 0.7942 - val_categorical_accuracy: 0.6900 - lr: 0.0010
# Epoch 2/5
# 40/42 [===========================>..] - ETA: 8s - loss: 0.2311 - categorical_accuracy: 0.9297 7
# 42/42 [==============================] - ETA: 0s - loss: 0.2325 - categorical_accuracy: 0.92764
#
# Epoch 00002: val_loss improved from 0.79425 to 0.49486, saving model to Model_TL_GRU_2_2022-01-0602_26_13.102719\model-00002-0.23245-0.92760-0.49486-0.79000.h5
# 42/42 [==============================] - 200s 5s/step - loss: 0.2325 - categorical_accuracy: 0.9276 - val_loss: 0.4949 - val_categorical_accuracy: 0.7900 - lr: 0.0010
# Epoch 3/5
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0899 - categorical_accuracy: 0.9719 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0923 - categorical_accuracy: 0.97134
#
# Epoch 00003: val_loss did not improve from 0.49486
# 42/42 [==============================] - 199s 5s/step - loss: 0.0923 - categorical_accuracy: 0.9713 - val_loss: 0.5012 - val_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 4/5
# 40/42 [===========================>..] - ETA: 10s - loss: 0.1012 - categorical_accuracy: 0.96887
# 42/42 [==============================] - ETA: 0s - loss: 0.1025 - categorical_accuracy: 0.96684
#
# Epoch 00004: val_loss improved from 0.49486 to 0.47092, saving model to Model_TL_GRU_2_2022-01-0602_26_13.102719\model-00004-0.10255-0.96682-0.47092-0.85000.h5
# 42/42 [==============================] - 225s 5s/step - loss: 0.1025 - categorical_accuracy: 0.9668 - val_loss: 0.4709 - val_categorical_accuracy: 0.8500 - lr: 0.0010
# Epoch 5/5
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1301 - categorical_accuracy: 0.9563 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1342 - categorical_accuracy: 0.95484
#
# Epoch 00005: val_loss improved from 0.47092 to 0.31424, saving model to Model_TL_GRU_2_2022-01-0602_26_13.102719\model-00005-0.13421-0.95475-0.31424-0.89000.h5
# 42/42 [==============================] - 219s 5s/step - loss: 0.1342 - categorical_accuracy: 0.9548 - val_loss: 0.3142 - val_categorical_accuracy: 0.8900 - lr: 0.0010

# %%
plot(model_gru_2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observations:**
#
# - Not getting the clear picture by using 5 epochs.
# - But model looks ok.

# %% [markdown]
# ## Model 7 : Using Conv2D + RNN  (Transfer Learning + GRU base model)

# %% [markdown]
# ##### In this model we are using model no 6 and increasing the number of epochs. Because we cann't predict using 5 epochs. So. lets re-observe after increasing the epochs from 5 to 20.

# %%
model_name = 'Model_TL_GRU_3' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


# Model 3 (Transfer Learning + GRU) Basic
mobilenet_TL = mobilenet.MobileNet(weights='imagenet', include_top=False)
model_gru_3 = Sequential()
model_gru_3.add(TimeDistributed(mobilenet_TL,input_shape=inputShape))

model_gru_3.add(TimeDistributed(BatchNormalization()))
model_gru_3.add(TimeDistributed(MaxPooling2D((2, 2))))
model_gru_3.add(TimeDistributed(Flatten()))

model_gru_3.add(GRU(64))
model_gru_3.add(Dropout(0.2))

model_gru_3.add(Dense(64,activation='relu'))

model_gru_3.add(Dense(5, activation='softmax'))

optimiser =Adam(0.001) #write your optimizer
model_gru_3.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_gru_3.summary())

# creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

num_epochs=20
model_gru_3=model_gru_3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,callbacks=callbacks_list, 
                    validation_data=val_generator,validation_steps=validation_steps,class_weight=None, workers=1, initial_epoch=0)
plot(model_gru_3)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_8 (TimeDis  (None, 15, 3, 3, 1024)   3228864
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 15, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 15, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 15, 1024)         0
#  stributed)
#
#  gru_2 (GRU)                 (None, 64)                209280
#
#  dropout_22 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 3,446,725
# Trainable params: 3,422,789
# Non-trainable params: 23,936
# _________________________________________________________________
# None
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 16
# Epoch 1/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.8634 - categorical_accuracy: 0.6672 7
# 42/42 [==============================] - ETA: 0s - loss: 0.8488 - categorical_accuracy: 0.6742Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 16
# 4
#
# Epoch 00001: val_loss improved from inf to 0.65594, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00001-0.84882-0.67421-0.65594-0.74000.h5
# 42/42 [==============================] - 224s 5s/step - loss: 0.8488 - categorical_accuracy: 0.6742 - val_loss: 0.6559 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 2/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1770 - categorical_accuracy: 0.9500 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1739 - categorical_accuracy: 0.95024
#
# Epoch 00002: val_loss did not improve from 0.65594
# 42/42 [==============================] - 221s 5s/step - loss: 0.1739 - categorical_accuracy: 0.9502 - val_loss: 0.8282 - val_categorical_accuracy: 0.7000 - lr: 0.0010
# Epoch 3/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1152 - categorical_accuracy: 0.9625 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1152 - categorical_accuracy: 0.96234
#
# Epoch 00003: val_loss improved from 0.65594 to 0.47480, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00003-0.11524-0.96229-0.47480-0.87000.h5
# 42/42 [==============================] - 221s 5s/step - loss: 0.1152 - categorical_accuracy: 0.9623 - val_loss: 0.4748 - val_categorical_accuracy: 0.8700 - lr: 0.0010
# Epoch 4/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0773 - categorical_accuracy: 0.9781 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0793 - categorical_accuracy: 0.97744
#
# Epoch 00004: val_loss improved from 0.47480 to 0.28275, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00004-0.07926-0.97738-0.28275-0.93000.h5
# 42/42 [==============================] - 221s 5s/step - loss: 0.0793 - categorical_accuracy: 0.9774 - val_loss: 0.2827 - val_categorical_accuracy: 0.9300 - lr: 0.0010
# Epoch 5/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0894 - categorical_accuracy: 0.9719 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0870 - categorical_accuracy: 0.97294
#
# Epoch 00005: val_loss did not improve from 0.28275
# 42/42 [==============================] - 221s 5s/step - loss: 0.0870 - categorical_accuracy: 0.9729 - val_loss: 0.6867 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1324 - categorical_accuracy: 0.9609 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1335 - categorical_accuracy: 0.95934
#
# Epoch 00006: val_loss improved from 0.28275 to 0.16670, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00006-0.13347-0.95928-0.16670-0.96000.h5
# 42/42 [==============================] - 221s 5s/step - loss: 0.1335 - categorical_accuracy: 0.9593 - val_loss: 0.1667 - val_categorical_accuracy: 0.9600 - lr: 0.0010
# Epoch 7/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1210 - categorical_accuracy: 0.9594 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1172 - categorical_accuracy: 0.96084
# 4
#
# Epoch 00007: val_loss did not improve from 0.16670
# 42/42 [==============================] - 219s 5s/step - loss: 0.1172 - categorical_accuracy: 0.9608 - val_loss: 0.6668 - val_categorical_accuracy: 0.8100 - lr: 0.0010
# Epoch 8/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1728 - categorical_accuracy: 0.9531 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1777 - categorical_accuracy: 0.95324
#
# Epoch 00008: val_loss did not improve from 0.16670
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 221s 5s/step - loss: 0.1777 - categorical_accuracy: 0.9532 - val_loss: 0.3898 - val_categorical_accuracy: 0.8700 - lr: 0.0010
# Epoch 9/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.0775 - categorical_accuracy: 0.98287
# 42/42 [==============================] - ETA: 0s - loss: 0.0770 - categorical_accuracy: 0.98194
#
# Epoch 00009: val_loss did not improve from 0.16670
# 42/42 [==============================] - 223s 5s/step - loss: 0.0770 - categorical_accuracy: 0.9819 - val_loss: 0.2073 - val_categorical_accuracy: 0.8800 - lr: 5.0000e-04
# Epoch 10/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.0210 - categorical_accuracy: 0.99377
# 42/42 [==============================] - ETA: 0s - loss: 0.0203 - categorical_accuracy: 0.99404
#
# Epoch 00010: val_loss improved from 0.16670 to 0.04590, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00010-0.02033-0.99397-0.04590-0.98000.h5
# 42/42 [==============================] - 225s 5s/step - loss: 0.0203 - categorical_accuracy: 0.9940 - val_loss: 0.0459 - val_categorical_accuracy: 0.9800 - lr: 5.0000e-04
# Epoch 11/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0063 - categorical_accuracy: 1.0000 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0108 - categorical_accuracy: 0.99704
#
# Epoch 00011: val_loss improved from 0.04590 to 0.04164, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00011-0.01076-0.99698-0.04164-0.99000.h5
# 42/42 [==============================] - 221s 5s/step - loss: 0.0108 - categorical_accuracy: 0.9970 - val_loss: 0.0416 - val_categorical_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 12/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0272 - categorical_accuracy: 0.9922 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0264 - categorical_accuracy: 0.99254
#
# Epoch 00012: val_loss did not improve from 0.04164
# 42/42 [==============================] - 221s 5s/step - loss: 0.0264 - categorical_accuracy: 0.9925 - val_loss: 0.0625 - val_categorical_accuracy: 0.9700 - lr: 5.0000e-04
# Epoch 13/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0102 - categorical_accuracy: 0.9969 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0099 - categorical_accuracy: 0.99704
#
# Epoch 00013: val_loss did not improve from 0.04164
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 220s 5s/step - loss: 0.0099 - categorical_accuracy: 0.9970 - val_loss: 0.1503 - val_categorical_accuracy: 0.9400 - lr: 5.0000e-04
# Epoch 14/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0108 - categorical_accuracy: 0.9984 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0106 - categorical_accuracy: 0.99854
# 4
#
# Epoch 00014: val_loss did not improve from 0.04164
# 42/42 [==============================] - 218s 5s/step - loss: 0.0106 - categorical_accuracy: 0.9985 - val_loss: 0.0883 - val_categorical_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 15/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0046 - categorical_accuracy: 1.0000 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0046 - categorical_accuracy: 1.00004
#
# Epoch 00015: val_loss did not improve from 0.04164
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 220s 5s/step - loss: 0.0046 - categorical_accuracy: 1.0000 - val_loss: 0.0716 - val_categorical_accuracy: 0.9900 - lr: 2.5000e-04
# Epoch 16/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0041 - categorical_accuracy: 1.0000 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0041 - categorical_accuracy: 1.00004
#
# Epoch 00016: val_loss did not improve from 0.04164
# 42/42 [==============================] - 224s 5s/step - loss: 0.0041 - categorical_accuracy: 1.0000 - val_loss: 0.1322 - val_categorical_accuracy: 0.9800 - lr: 1.2500e-04
# Epoch 17/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.0052 - categorical_accuracy: 0.99847
# 42/42 [==============================] - ETA: 0s - loss: 0.0051 - categorical_accuracy: 0.99854
#
# Epoch 00017: val_loss improved from 0.04164 to 0.01098, saving model to Model_TL_GRU_3_2022-01-0602_26_13.102719\model-00017-0.00509-0.99849-0.01098-1.00000.h5
# 42/42 [==============================] - 227s 5s/step - loss: 0.0051 - categorical_accuracy: 0.9985 - val_loss: 0.0110 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 18/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0032 - categorical_accuracy: 1.0000 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0032 - categorical_accuracy: 1.00004
#
# Epoch 00018: val_loss did not improve from 0.01098
# 42/42 [==============================] - 220s 5s/step - loss: 0.0032 - categorical_accuracy: 1.0000 - val_loss: 0.1427 - val_categorical_accuracy: 0.9700 - lr: 1.2500e-04
# Epoch 19/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0050 - categorical_accuracy: 1.0000 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0048 - categorical_accuracy: 1.00004
#
# Epoch 00019: val_loss did not improve from 0.01098
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 219s 5s/step - loss: 0.0048 - categorical_accuracy: 1.0000 - val_loss: 0.0123 - val_categorical_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 20/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0035 - categorical_accuracy: 0.9984 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0035 - categorical_accuracy: 0.99854
#
# Epoch 00020: val_loss did not improve from 0.01098
# 42/42 [==============================] - 221s 5s/step - loss: 0.0035 - categorical_accuracy: 0.9985 - val_loss: 0.0738 - val_categorical_accuracy: 0.9900 - lr: 6.2500e-05

# %%
plot(model_gru_3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observations:**
#
# - This model seems to be the best yet.
# - Taining Accuracy lies between: 95-98
# - Validation Accuracy lies between: 92-95

# %% [markdown]
# ## Model 8 : Using Conv2D + RNN  (Transfer Learning + GRU base model)

# %% [markdown]
# ##### We will try to reduce the training and validation gap a little more.

# %%
model_name = 'Model_TL_GRU_5' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)# write the REducelronplateau code here
callbacks_list = [checkpoint,LR]


# Model 4 (Transfer Learning + GRU) Basic
mobilenet_TL = mobilenet.MobileNet(weights='imagenet', include_top=False)
model_gru_5 = Sequential()
model_gru_5.add(TimeDistributed(mobilenet_TL,input_shape=inputShape))

model_gru_5.add(TimeDistributed(BatchNormalization()))
model_gru_5.add(TimeDistributed(MaxPooling2D((2, 2))))
model_gru_5.add(TimeDistributed(Flatten()))

model_gru_5.add(GRU(64))
model_gru_5.add(Dropout(0.5))

model_gru_5.add(Dense(64,activation='relu'))
model_gru_5.add(Dropout(0.5))

model_gru_5.add(Dense(5, activation='softmax'))

optimiser =Adam(0.001) #write your optimizer
model_gru_5.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_gru_5.summary())

# creating the `train_generator` and the `val_generator` which will be used in `.fit_generator`
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

num_epochs=20
model_gru_5=model_gru_5.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,callbacks=callbacks_list, 
                    validation_data=val_generator,validation_steps=validation_steps,class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_12 (TimeDi  (None, 15, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 15, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 15, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 15, 1024)         0
#  stributed)
#
#  gru_3 (GRU)                 (None, 64)                209280
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dropout_24 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 3,446,725
# Trainable params: 3,422,789
# Non-trainable params: 23,936
# _________________________________________________________________
# None
# Source path =  C:/Users\King/Desktop/Project_data/train ; batch size = 16
# Epoch 1/20
# 40/42 [===========================>..] - ETA: 10s - loss: 1.6806 - categorical_accuracy: 0.30637
# 42/42 [==============================] - ETA: 0s - loss: 1.6667 - categorical_accuracy: 0.3152Source path =  C:/Users\King/Desktop/Project_data/val ; batch size = 16
# 4
#
# Epoch 00001: val_loss improved from inf to 1.34389, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00001-1.66666-0.31523-1.34389-0.57000.h5
# 42/42 [==============================] - 229s 5s/step - loss: 1.6667 - categorical_accuracy: 0.3152 - val_loss: 1.3439 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 2/20
# 40/42 [===========================>..] - ETA: 9s - loss: 1.0199 - categorical_accuracy: 0.6016 7
# 42/42 [==============================] - ETA: 0s - loss: 1.0166 - categorical_accuracy: 0.60184
#
# Epoch 00002: val_loss improved from 1.34389 to 0.86220, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00002-1.01661-0.60181-0.86220-0.67000.h5
# 42/42 [==============================] - 224s 5s/step - loss: 1.0166 - categorical_accuracy: 0.6018 - val_loss: 0.8622 - val_categorical_accuracy: 0.6700 - lr: 0.0010
# Epoch 3/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.6344 - categorical_accuracy: 0.76417
# 42/42 [==============================] - ETA: 0s - loss: 0.6217 - categorical_accuracy: 0.76924
#
# Epoch 00003: val_loss improved from 0.86220 to 0.36422, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00003-0.62172-0.76923-0.36422-0.84000.h5
# 42/42 [==============================] - 229s 5s/step - loss: 0.6217 - categorical_accuracy: 0.7692 - val_loss: 0.3642 - val_categorical_accuracy: 0.8400 - lr: 0.0010
# Epoch 4/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.4092 - categorical_accuracy: 0.87507
# 42/42 [==============================] - ETA: 0s - loss: 0.4086 - categorical_accuracy: 0.87334
#
# Epoch 00004: val_loss improved from 0.36422 to 0.27866, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00004-0.40860-0.87330-0.27866-0.88000.h5
# 42/42 [==============================] - 228s 5s/step - loss: 0.4086 - categorical_accuracy: 0.8733 - val_loss: 0.2787 - val_categorical_accuracy: 0.8800 - lr: 0.0010
# Epoch 5/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.2211 - categorical_accuracy: 0.94227
# 42/42 [==============================] - ETA: 0s - loss: 0.2153 - categorical_accuracy: 0.94424
#
# Epoch 00005: val_loss did not improve from 0.27866
# 42/42 [==============================] - 225s 5s/step - loss: 0.2153 - categorical_accuracy: 0.9442 - val_loss: 0.2924 - val_categorical_accuracy: 0.9000 - lr: 0.0010
# Epoch 6/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1870 - categorical_accuracy: 0.9500 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1877 - categorical_accuracy: 0.95024
#
# Epoch 00006: val_loss did not improve from 0.27866
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 219s 5s/step - loss: 0.1877 - categorical_accuracy: 0.9502 - val_loss: 0.3775 - val_categorical_accuracy: 0.8700 - lr: 0.0010
# Epoch 7/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.2141 - categorical_accuracy: 0.9516 7
# 42/42 [==============================] - ETA: 0s - loss: 0.2110 - categorical_accuracy: 0.95024
# 4
#
# Epoch 00007: val_loss did not improve from 0.27866
# 42/42 [==============================] - 218s 5s/step - loss: 0.2110 - categorical_accuracy: 0.9502 - val_loss: 0.3031 - val_categorical_accuracy: 0.9200 - lr: 5.0000e-04
# Epoch 8/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1410 - categorical_accuracy: 0.9656 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1375 - categorical_accuracy: 0.96684
#
# Epoch 00008: val_loss improved from 0.27866 to 0.19988, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00008-0.13751-0.96682-0.19988-0.95000.h5
# 42/42 [==============================] - 220s 5s/step - loss: 0.1375 - categorical_accuracy: 0.9668 - val_loss: 0.1999 - val_categorical_accuracy: 0.9500 - lr: 5.0000e-04
# Epoch 9/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.1013 - categorical_accuracy: 0.9781 7
# 42/42 [==============================] - ETA: 0s - loss: 0.1006 - categorical_accuracy: 0.97894
#
# Epoch 00009: val_loss improved from 0.19988 to 0.05553, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00009-0.10058-0.97888-0.05553-0.99000.h5
# 42/42 [==============================] - 219s 5s/step - loss: 0.1006 - categorical_accuracy: 0.9789 - val_loss: 0.0555 - val_categorical_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 10/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0829 - categorical_accuracy: 0.9828 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0829 - categorical_accuracy: 0.98194
#
# Epoch 00010: val_loss improved from 0.05553 to 0.02121, saving model to Model_TL_GRU_5_2022-01-0602_26_13.102719\model-00010-0.08293-0.98190-0.02121-0.99000.h5
# 42/42 [==============================] - 220s 5s/step - loss: 0.0829 - categorical_accuracy: 0.9819 - val_loss: 0.0212 - val_categorical_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 11/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0684 - categorical_accuracy: 0.9844 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0679 - categorical_accuracy: 0.98494
#
# Epoch 00011: val_loss did not improve from 0.02121
# 42/42 [==============================] - 220s 5s/step - loss: 0.0679 - categorical_accuracy: 0.9849 - val_loss: 0.0312 - val_categorical_accuracy: 0.9900 - lr: 5.0000e-04
# Epoch 12/20
# 40/42 [===========================>..] - ETA: 10s - loss: 0.0770 - categorical_accuracy: 0.98447
# 42/42 [==============================] - ETA: 0s - loss: 0.0799 - categorical_accuracy: 0.98344
#
# Epoch 00012: val_loss did not improve from 0.02121
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 228s 5s/step - loss: 0.0799 - categorical_accuracy: 0.9834 - val_loss: 0.1369 - val_categorical_accuracy: 0.9500 - lr: 5.0000e-04
# Epoch 13/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0546 - categorical_accuracy: 0.9922 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0745 - categorical_accuracy: 0.99104
#
# Epoch 00013: val_loss did not improve from 0.02121
# 42/42 [==============================] - 220s 5s/step - loss: 0.0745 - categorical_accuracy: 0.9910 - val_loss: 0.1949 - val_categorical_accuracy: 0.9700 - lr: 2.5000e-04
# Epoch 14/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0430 - categorical_accuracy: 0.9922 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0419 - categorical_accuracy: 0.99254
# 4
#
# Epoch 00014: val_loss did not improve from 0.02121
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 219s 5s/step - loss: 0.0419 - categorical_accuracy: 0.9925 - val_loss: 0.1158 - val_categorical_accuracy: 0.9600 - lr: 2.5000e-04
# Epoch 15/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0424 - categorical_accuracy: 0.9891 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0428 - categorical_accuracy: 0.98944
#
# Epoch 00015: val_loss did not improve from 0.02121
# 42/42 [==============================] - 219s 5s/step - loss: 0.0428 - categorical_accuracy: 0.9894 - val_loss: 0.1910 - val_categorical_accuracy: 0.9600 - lr: 1.2500e-04
# Epoch 16/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0468 - categorical_accuracy: 0.9937 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0468 - categorical_accuracy: 0.99404
#
# Epoch 00016: val_loss did not improve from 0.02121
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 220s 5s/step - loss: 0.0468 - categorical_accuracy: 0.9940 - val_loss: 0.0827 - val_categorical_accuracy: 0.9800 - lr: 1.2500e-04
# Epoch 17/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0264 - categorical_accuracy: 0.9953 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0258 - categorical_accuracy: 0.99554
#
# Epoch 00017: val_loss did not improve from 0.02121
# 42/42 [==============================] - 219s 5s/step - loss: 0.0258 - categorical_accuracy: 0.9955 - val_loss: 0.0790 - val_categorical_accuracy: 0.9800 - lr: 6.2500e-05
# Epoch 18/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0402 - categorical_accuracy: 0.9937 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0397 - categorical_accuracy: 0.99404
#
# Epoch 00018: val_loss did not improve from 0.02121
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 42/42 [==============================] - 219s 5s/step - loss: 0.0397 - categorical_accuracy: 0.9940 - val_loss: 0.1205 - val_categorical_accuracy: 0.9700 - lr: 6.2500e-05
# Epoch 19/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0462 - categorical_accuracy: 0.9937 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0453 - categorical_accuracy: 0.99404
#
# Epoch 00019: val_loss did not improve from 0.02121
# 42/42 [==============================] - 220s 5s/step - loss: 0.0453 - categorical_accuracy: 0.9940 - val_loss: 0.1483 - val_categorical_accuracy: 0.9600 - lr: 3.1250e-05
# Epoch 20/20
# 40/42 [===========================>..] - ETA: 9s - loss: 0.0375 - categorical_accuracy: 0.9906 7
# 42/42 [==============================] - ETA: 0s - loss: 0.0375 - categorical_accuracy: 0.99104
#
# Epoch 00020: val_loss did not improve from 0.02121
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 42/42 [==============================] - 220s 5s/step - loss: 0.0375 - categorical_accuracy: 0.9910 - val_loss: 0.0842 - val_categorical_accuracy: 0.9800 - lr: 3.1250e-05

# %%
plot(model_gru_5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Observations:**
#
# - This model also looks good but not better than model 7.
# - Training Accuracy lies between: 94-97
# - Validation Accuracy lies between: 88-92

# %% [markdown]
# # Interpretation :

# %% [markdown]
# ## Out of all the Conv 3D and Conv 2D + RNN models we can proceed with Model 7 as it attained higher accuracy and stability

# %%
# Viewing Model 7

plot(model_gru_3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
